# %%
#Shiqi Zhang, Tyler Stevenson, Zefeng Pei
import numpy as np
import pandas as pd
pd.set_option('max_colwidth', 600)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='darkgrid', font_scale=1.6)
import spacy
import random
from gensim import models, corpora, similarities
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer


#import discussion json file to dataframe
disc_shar = pd.read_json('20231012_235320_discussion_sharings.json')
disc_shar = pd.json_normalize(disc_shar['Sources'])

disc_shar.head()
# Out:
#          Type  \
# 0  discussion
# 1  discussion
# 2  discussion
# 3  discussion
# 4  discussion
#
#                                                                              URL  \
# 0                              https://github.com/xihajun/Projects/discussions/3
# 1                              https://github.com/vueuse/vueuse/discussions/3355
# 2                      https://github.com/huangyinhaow/blogGiscus/discussions/11
# 3                            https://github.com/git-lfs/git-lfs/discussions/5457
# 4  https://github.com/prgrms-fe-devcourse/FEDC4_HONKOK_JunilHwang/discussions/47
#
#       Author                                     RepoName      RepoLanguage  \
# 0    xihajun                             xihajun/Projects  Jupyter Notebook
# 1  bobmulder                                vueuse/vueuse        TypeScript
# 2     giscus                      huangyinhaow/blogGiscus              None
# 3     ggrrll                              git-lfs/git-lfs                Go
# ...

# %%
#import issue json file to dataframe
issue_shar = pd.read_json('20231012_235128_issue_sharings.json')
issue_shar = pd.json_normalize(issue_shar['Sources'])
issue_shar.head()
# Out:
#     Type                                                          URL  \
# 0  issue       https://github.com/ShogoHirasawa/2023-syuron/issues/19
# 1  issue  https://github.com/CitizensFoundation/policy-synth/issues/2
# 2  issue           https://github.com/arakoodev/EdgeChains/issues/244
# 3  issue             https://github.com/maxoja/jampify-core/issues/69
# 4  issue            https://github.com/JCKalt/General-Work/issues/130
#
#           Author                         RepoName RepoLanguage  Number  \
# 0  ShogoHirasawa        ShogoHirasawa/2023-syuron         None      19
# 1     rbjarnason  CitizensFoundation/policy-synth   TypeScript       2
# 2       adrianog             arakoodev/EdgeChains         Java     244
# 3         maxoja              maxoja/jampify-core       Python      69
# 4         JCKalt              JCKalt/General-Work         None     130
#
#                                                                  Title  \
# ...

# %%
# Get the common authors between both DataFrames
common_authors = set(issue_shar['Author']) & set(disc_shar['Author'])

# Get the common repos between both DataFrames
common_repo = set(issue_shar['RepoName']) & set(disc_shar['RepoName'])

# %%
# Create a new dataframe that has all the authors and repos that have a comment and issue
issue = issue_shar[(issue_shar['Author'].isin(common_authors)) | (issue_shar['RepoName'].isin(common_repo))]
disc = disc_shar[(disc_shar['Author'].isin(common_authors)) | (disc_shar['RepoName'].isin(common_repo))]
data_total = pd.concat([issue, disc], axis=0, ignore_index=True)
data_total.head()
# Out:
#     Type  \
# 0  issue
# 1  issue
# 2  issue
# 3  issue
# 4  issue
#
#                                                                          URL  \
# 0                             https://github.com/ubiquity/research/issues/57
# 1                         https://github.com/sleuthkit/sleuthkit/issues/2872
# 2                          https://github.com/ubiquity/sponsorships/issues/2
# 3                    https://github.com/clojure-emacs/clj-suitable/issues/39
# 4  https://github.com/deep-foundation/js-docker-isolation-provider/issues/15
#
#            Author                                      RepoName RepoLanguage  \
# 0       pavlovcik                             ubiquity/research         None
# 1          nyck33                           sleuthkit/sleuthkit            C
# 2       pavlovcik                         ubiquity/sponsorships         None
# 3            vemv                    clojure-emacs/clj-suitable      Clojure
# ...

# %%
# Create corpus from the 'Body' column of the 'data_total' DataFrame
corpus_total = data_total['Body'].tolist()

# Function to preprocess text (convert to lowercase)
def preprocess_text(text_total):
    return text_total.lower()

# Preprocess each document in the corpus
processed_corpus_total = [preprocess_text(text_total) for text_total in corpus_total]

# Load the spacy model for text processing
nlp = spacy.load("en_core_web_sm")

# Function to tokenize and lemmatize text, while removing punctuation, special characters, and stop words
def process_text(entry_total):
    # Apply spaCy pipeline to the entry (tokenization, lemmatization, etc.)
    doc = nlp(entry_total)
    
    # Return lemmatized tokens, excluding punctuation, spaces, non-alphanumeric characters, and stop words
    return [token.lemma_ for token in doc if not token.is_punct and not token.is_space and token.is_alpha and not token.is_stop]

# Process each document in the corpus using the function defined above
token_corpus_total = [process_text(entry_total) for entry_total in processed_corpus_total]

# Build a dictionary from the processed corpus (mapping token to unique ID)
dct_total = corpora.Dictionary(token_corpus_total)

# Convert the processed corpus into a Bag-of-Words (BoW) representation
bow_total = [dct_total.doc2bow(i) for i in token_corpus_total]

# Train an LDA (Latent Dirichlet Allocation) model on the Bag-of-Words representation
lda_model_total = models.LdaModel(corpus=bow_total, num_topics=10, passes=10, alpha='auto', eta='auto', id2word=dct_total, random_state=0)

# Get the topics for the corpus
topics_total = list(lda_model_total.get_document_topics(bow_total, minimum_probability=0))

# Print the proportion of each topic in the corpus
for i in range(10):
    print(f"Topic {i} proportion: {100 * sum([pair[i][1] for pair in topics_total]) / len(topics_total):.1f}%")

# Print the top words for each topic in the LDA model
lda_model_total.print_topics()
# Out:
# Topic 0 proportion: 6.3%
# Topic 1 proportion: 10.1%
# Topic 2 proportion: 12.5%
# Topic 3 proportion: 13.8%
# Topic 4 proportion: 7.4%
# Topic 5 proportion: 12.3%
# Topic 6 proportion: 0.3%
# Topic 7 proportion: 8.3%
# Topic 8 proportion: 17.4%
# Topic 9 proportion: 11.6%
# [(0,
#   '0.076*"const" + 0.054*"log" + 0.038*"await" + 0.026*"throw" + 0.026*"new" + 0.025*"triggeredbylinkid" + 0.021*"containtypelinkid" + 0.020*"link" + 0.020*"datum" + 0.019*"result"'),
#  (1,
#   '0.037*"file" + 0.037*"puppeteer" + 0.025*"run" + 0.020*"lib" + 0.020*"bun" + 0.015*"error" + 0.015*"binary" + 0.012*"create" + 0.012*"core" + 0.012*"world"'),
#  (2,
#   '0.045*"solar" + 0.023*"load" + 0.016*"tesla" + 0.013*"feature" + 0.013*"key" + 0.013*"production" + 0.013*"negative" + 0.013*"panel" + 0.013*"powerwall" + 0.013*"value"'),
#  (3,
# ...

# %%
# Plot word clouds for each topic
word_cloud = WordCloud(background_color='white', max_words=10)
fig, axes = plt.subplots(3, 3, figsize=(20,15))

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(lda_model_total.show_topic(i))
    word_cloud.generate_from_frequencies(topic_words)
    plt.gca().imshow(word_cloud, interpolation='bilinear')
    plt.gca().set_title(f'Topic {i}')
    plt.gca().axis('off')
plt.show()

# %%
# create a new dataframe that only has issues that were resolved
data_closed = data_total[data_total['State'] == 'CLOSED']
data_closed.head()
# Out:
#      Type                                                             URL  \
# 7   issue             https://github.com/clojure-emacs/orchard/issues/186
# 11  issue            https://github.com/epicweb-dev/epic-stack/issues/248
# 12  issue  https://github.com/simonhamp/laravel-nova-csv-import/issues/70
# 13  issue      https://github.com/JushBJJ/Mr.-Ranedeer-AI-Tutor/issues/68
# 14  issue                https://github.com/inertiajs/inertia/issues/1645
#
#              Author                           RepoName RepoLanguage  Number  \
# 7              vemv              clojure-emacs/orchard      Clojure     186
# 11  DigitalGoldfish             epicweb-dev/epic-stack   TypeScript     248
# 12      HeadStudios  simonhamp/laravel-nova-csv-import          PHP      70
# 13       inquiloper      JushBJJ/Mr.-Ranedeer-AI-Tutor         None      68
# 14      Bloemendaal                  inertiajs/inertia          PHP    1645
#
# ...

# %%
# Create corpus from the 'Body' column of the 'data_closed' DataFrame
corpus_closed = data_closed['Body'].tolist()

# Function to preprocess text (convert to lowercase)
def preprocess_text(text_closed):
    return text_closed.lower()

# Preprocess each document in the corpus
processed_corpus_closed = [preprocess_text(text_closed) for text_closed in corpus_closed]

# Load the spaCy model for text processing
nlp = spacy.load("en_core_web_sm")

# Function to tokenize and lemmatize text, while removing punctuation, special characters, and stop words
def process_text(entry_closed):
    # Apply spaCy pipeline to the entry (tokenization, lemmatization, etc.)
    doc = nlp(entry_closed)
    
    # Return lemmatized tokens, excluding punctuation, spaces, non-alphanumeric characters, and stop words
    return [token.lemma_ for token in doc if not token.is_punct and not token.is_space and token.is_alpha and not token.is_stop]

# Process each document in the corpus using the function defined above
token_corpus_closed = [process_text(entry_closed) for entry_closed in processed_corpus_closed]

# Build a dictionary from the processed corpus (mapping token to unique ID)
dct_closed = corpora.Dictionary(token_corpus_closed)

# Convert the processed corpus into a Bag-of-Words (BoW) representation
bow_closed = [dct_closed.doc2bow(i) for i in token_corpus_closed]

# Train an LDA (Latent Dirichlet Allocation) model on the Bag-of-Words representation
lda_model_closed = models.LdaModel(corpus=bow_closed, num_topics=10, passes=10, alpha='auto', eta='auto', id2word=dct_closed, random_state=0)

# Get the topics for the corpus
topics_closed = list(lda_model_closed.get_document_topics(bow_closed, minimum_probability=0))

# Print the proportion of each topic in the corpus
for i in range(10):
    print(f"Topic {i} proportion: {100 * sum([pair[i][1] for pair in topics_closed]) / len(topics_closed):.1f}%")

# Print the top words for each topic in the LDA model
lda_model_closed.print_topics()
# Out:
# Topic 0 proportion: 24.3%
# Topic 1 proportion: 0.2%
# Topic 2 proportion: 18.7%
# Topic 3 proportion: 0.2%
# Topic 4 proportion: 12.0%
# Topic 5 proportion: 12.5%
# Topic 6 proportion: 0.2%
# Topic 7 proportion: 12.7%
# Topic 8 proportion: 12.8%
# Topic 9 proportion: 6.5%
# [(0,
#   '0.038*"navigation" + 0.025*"change" + 0.025*"forward" + 0.025*"event" + 0.021*"unsaved" + 0.017*"debit" + 0.017*"create" + 0.017*"browser" + 0.017*"inertia" + 0.017*"cancel"'),
#  (1,
#   '0.003*"solar" + 0.002*"load" + 0.002*"value" + 0.002*"panel" + 0.002*"negative" + 0.002*"tesla" + 0.002*"bucket" + 0.002*"image" + 0.002*"powerwall" + 0.002*"system"'),
#  (2,
#   '0.028*"follow" + 0.028*"bucket" + 0.023*"file" + 0.017*"version" + 0.017*"image" + 0.012*"try" + 0.012*"gpt" + 0.012*"prompt" + 0.012*"bot" + 0.012*"disk"'),
#  (3,
#   '0.002*"navigation" + 0.002*"config" + 0.002*"hour" + 0.002*"tcp" + 0.002*"change" + 0.002*"camelcase" + 0.002*"minute" + 0.002*"ago" + 0.002*"event" + 0.002*"unsaved"'),
# ...

# %%
# Plot word clouds for each topic
word_cloud = WordCloud(background_color='white', max_words=10)
fig, axes = plt.subplots(3, 3, figsize=(20,15))

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(lda_model_closed.show_topic(i))
    word_cloud.generate_from_frequencies(topic_words)
    plt.gca().imshow(word_cloud, interpolation='bilinear')
    plt.gca().set_title(f'Topic {i}')
    plt.gca().axis('off')
plt.show()

# %%
# create a new dataframe that only has issues that werent resolved
data_open = data_total[data_total['State'] == 'OPEN']
data_open.head()
# Out:
#     Type  \
# 0  issue
# 1  issue
# 2  issue
# 3  issue
# 4  issue
#
#                                                                          URL  \
# 0                             https://github.com/ubiquity/research/issues/57
# 1                         https://github.com/sleuthkit/sleuthkit/issues/2872
# 2                          https://github.com/ubiquity/sponsorships/issues/2
# 3                    https://github.com/clojure-emacs/clj-suitable/issues/39
# 4  https://github.com/deep-foundation/js-docker-isolation-provider/issues/15
#
#            Author                                      RepoName RepoLanguage  \
# 0       pavlovcik                             ubiquity/research         None
# 1          nyck33                           sleuthkit/sleuthkit            C
# 2       pavlovcik                         ubiquity/sponsorships         None
# 3            vemv                    clojure-emacs/clj-suitable      Clojure
# ...

# %%
# Create corpus from the 'Body' column of the 'df3' DataFrame
corpus_open = data_open['Body'].tolist()

# Function to preprocess text (convert to lowercase)
def preprocess_text(text_open):
    return text_open.lower()

# Preprocess each document in the corpus
processed_corpus_open = [preprocess_text(text_open) for text_open in corpus_open]

# Load the spaCy model for text processing
nlp = spacy.load("en_core_web_sm")

# Function to tokenize and lemmatize text, while removing punctuation, special characters, and stop words
def process_text(entry_open):
    # Apply spaCy pipeline to the entry (tokenization, lemmatization, etc.)
    doc = nlp(entry_open)
    
    # Return lemmatized tokens, excluding punctuation, spaces, non-alphanumeric characters, and stop words
    return [token.lemma_ for token in doc if not token.is_punct and not token.is_space and token.is_alpha and not token.is_stop]

# Process each document in the corpus using the function defined above
token_corpus_open = [process_text(entry_open) for entry_open in processed_corpus_open]

# Build a dictionary from the processed corpus (mapping token to unique ID)
dct_open = corpora.Dictionary(token_corpus_open)

# Convert the processed corpus into a Bag-of-Words (BoW) representation
bow_open = [dct_open.doc2bow(i) for i in token_corpus_open]

# Train an LDA (Latent Dirichlet Allocation) model on the Bag-of-Words representation
lda_model_open = models.LdaModel(corpus=bow_open, num_topics=10, passes=10, alpha='auto', eta='auto', id2word=dct_open, random_state=0)

# Get the topics for the corpus
topics_open = list(lda_model_open.get_document_topics(bow_open, minimum_probability=0))

# Print the proportion of each topic in the corpus
for i in range(10):
    print(f"Topic {i} proportion: {100 * sum([pair[i][1] for pair in topics_open]) / len(topics_open):.1f}%")

# Print the top words for each topic in the LDA model
lda_model_open.print_topics()
# Out:
# Topic 0 proportion: 26.2%
# Topic 1 proportion: 9.2%
# Topic 2 proportion: 0.7%
# Topic 3 proportion: 9.2%
# Topic 4 proportion: 0.6%
# Topic 5 proportion: 9.0%
# Topic 6 proportion: 9.0%
# Topic 7 proportion: 17.7%
# Topic 8 proportion: 0.7%
# Topic 9 proportion: 17.6%
# [(0,
#   '0.031*"request" + 0.031*"pull" + 0.026*"code" + 0.021*"require" + 0.021*"specification" + 0.021*"issue" + 0.016*"link" + 0.016*"error" + 0.016*"work" + 0.016*"chatgpt"'),
#  (1,
#   '0.071*"file" + 0.044*"bun" + 0.044*"run" + 0.033*"binary" + 0.028*"world" + 0.022*"create" + 0.022*"javascript" + 0.017*"code" + 0.017*"content" + 0.017*"hello"'),
#  (2,
#   '0.003*"file" + 0.003*"const" + 0.003*"run" + 0.003*"log" + 0.003*"binary" + 0.003*"await" + 0.003*"code" + 0.003*"bun" + 0.003*"datum" + 0.002*"error"'),
#  (3,
#   '0.090*"const" + 0.067*"log" + 0.047*"await" + 0.032*"new" + 0.032*"throw" + 0.031*"triggeredbylinkid" + 0.026*"containtypelinkid" + 0.025*"datum" + 0.023*"result" + 0.022*"link"'),
#  (4,
# ...

# %%
# Plot word clouds for each topic
word_cloud = WordCloud(background_color='white', max_words=10)
fig, axes = plt.subplots(3, 3, figsize=(20,15))

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(lda_model_open.show_topic(i))
    word_cloud.generate_from_frequencies(topic_words)
    plt.gca().imshow(word_cloud, interpolation='bilinear')
    plt.gca().set_title(f'Topic {i}')
    plt.gca().axis('off')
plt.show()

# %%
# Get the top 10 topics for open state
topics_open = lda_model_open.print_topics(num_topics=10, num_words=5)
print("Top 10 Topics for Open:")
for topic in topics_open:
    print(topic)

# Get the top 10 topics for closed state
topics_closed = lda_model_closed.print_topics(num_topics=10, num_words=5)
print("\nTop 10 Topics for Closed:")
for topic in topics_closed:
    print(topic)

# Get the top 10 topics for total state
topics_total = lda_model_total.print_topics(num_topics=10, num_words=5)
print("\nTop 10 Topics for Total")
for topic in topics_total:
    print(topic)
# Out:
# Top 10 Topics for Open:
# (0, '0.031*"request" + 0.031*"pull" + 0.026*"code" + 0.021*"require" + 0.021*"specification"')
# (1, '0.071*"file" + 0.044*"bun" + 0.044*"run" + 0.033*"binary" + 0.028*"world"')
# (2, '0.003*"file" + 0.003*"const" + 0.003*"run" + 0.003*"log" + 0.003*"binary"')
# (3, '0.090*"const" + 0.067*"log" + 0.047*"await" + 0.032*"new" + 0.032*"throw"')
# (4, '0.003*"const" + 0.003*"log" + 0.003*"await" + 0.002*"throw" + 0.002*"link"')
# (5, '0.059*"feature" + 0.059*"key" + 0.030*"imagery" + 0.016*"code" + 0.016*"chatgpt"')
# (6, '0.017*"file" + 0.017*"like" + 0.017*"image" + 0.017*"etc" + 0.017*"mathematic"')
# (7, '0.024*"review" + 0.024*"agent" + 0.018*"task" + 0.018*"request" + 0.015*"contributor"')
# (8, '0.002*"task" + 0.002*"const" + 0.002*"key" + 0.002*"feature" + 0.002*"log"')
# (9, '0.038*"devpool" + 0.038*"pitchdeck" + 0.022*"open" + 0.017*"partner" + 0.017*"idea"')
#
# Top 10 Topics for Closed:
# ...

# %%
# Function to process text (tokenize and lemmatize, removing stop words and punctuation)
def process_text_closed(entry_closed):
    doc = nlp(entry_closed)
    return " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.is_alpha])

# Apply the processing function to each document
processed_corpus_closed = [process_text_closed(text_closed) for text_closed in processed_corpus_closed]

# Initialize the TfidfVectorizer from scikit-learn
tfidf_vectorizer_closed = TfidfVectorizer()

# Fit and transform the corpus to get the TF-IDF matrix
tfidf_matrix_closed = tfidf_vectorizer_closed.fit_transform(processed_corpus_closed)

# Get the feature names (terms)
terms_closed = tfidf_vectorizer_closed.get_feature_names_out()

# Calculate the average TF-IDF score for each term across the entire corpus
average_tfidf_scores_closed = np.mean(tfidf_matrix_closed.toarray(), axis=0)

# Combine terms and their average TF-IDF scores into a list of tuples
term_scores_closed = list(zip(terms_closed, average_tfidf_scores_closed))

# Sort the terms by their average TF-IDF score in descending order
sorted_term_scores_closed = sorted(term_scores_closed, key=lambda x: x[1], reverse=True)

# Get the top N overall keywords for the entire corpus
top_n_closed = 10
top_keywords_closed = sorted_term_scores_closed[:top_n_closed]

# Print the top N keywords and their average TF-IDF scores
print(f"Top {top_n_closed} overall keywords for the closed corpus:")
for word_closed, score_closed in top_keywords_closed:
    print(f"  {word_closed}: {score_closed:.3f}")
# Out:
# Top 10 overall keywords for the closed corpus:
#   issue: 0.069
#   solar: 0.043
#   resolve: 0.042
#   tutor: 0.042
#   like: 0.041
#   jushbjj: 0.041
#   link: 0.039
#   ai: 0.038
#   debit: 0.038
#   config: 0.038

# %%
# Function to process text (tokenize and lemmatize, removing stop words and punctuation)
def process_text_open(entry_open):
    doc = nlp(entry_open)
    return " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.is_alpha])

# Apply the processing function to each document
processed_corpus_open = [process_text_open(text_open) for text_open in processed_corpus_open]

# Initialize the TfidfVectorizer from scikit-learn
tfidf_vectorizer_open = TfidfVectorizer()

# Fit and transform the corpus to get the TF-IDF matrix
tfidf_matrix_open = tfidf_vectorizer_open.fit_transform(processed_corpus_open)

# Get the feature names (terms)
terms_open = tfidf_vectorizer_open.get_feature_names_out()

# Calculate the average TF-IDF score for each term across the entire corpus
average_tfidf_scores_open = np.mean(tfidf_matrix_open.toarray(), axis=0)

# Combine terms and their average TF-IDF scores into a list of tuples
term_scores_open = list(zip(terms_open, average_tfidf_scores_open))

# Sort the terms by their average TF-IDF score in descending order
sorted_term_scores_open = sorted(term_scores_open, key=lambda x: x[1], reverse=True)

# Get the top N overall keywords for the entire corpus
top_n_open = 10
top_keywords_open = sorted_term_scores_open[:top_n_open]

# Print the top N keywords and their average TF-IDF scores
print(f"Top {top_n_open} overall keywords for the open corpus:")
for word_open, score_open in top_keywords_open:
    print(f"  {word_open}: {score_open:.3f}")
# Out:
# Top 10 overall keywords for the open corpus:
#   file: 0.062
#   const: 0.060
#   request: 0.058
#   task: 0.051
#   pull: 0.049
#   feature: 0.049
#   key: 0.049
#   code: 0.049
#   require: 0.047
#   review: 0.044

# %%
# Function to process text (tokenize and lemmatize, removing stop words and punctuation)
def process_text_total(entry_total):
    doc = nlp(entry_total)
    return " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.is_alpha])

# Apply the processing function to each document
processed_corpus_total = [process_text_total(text_total) for text_total in processed_corpus_total]

# Initialize the TfidfVectorizer from scikit-learn
tfidf_vectorizer_total = TfidfVectorizer()

# Fit and transform the corpus to get the TF-IDF matrix
tfidf_matrix_total = tfidf_vectorizer_total.fit_transform(processed_corpus_total)

# Get the feature names (terms)
terms_total = tfidf_vectorizer_total.get_feature_names_out()

# Calculate the average TF-IDF score for each term across the entire corpus
average_tfidf_scores_total = np.mean(tfidf_matrix_total.toarray(), axis=0)

# Combine terms and their average TF-IDF scores into a list of tuples
term_scores_total = list(zip(terms_total, average_tfidf_scores_total))

# Sort the terms by their average TF-IDF score in descending order
sorted_term_scores_total = sorted(term_scores_total, key=lambda x: x[1], reverse=True)

# Get the top N overall keywords for the entire corpus
top_n_total = 10
top_keywords_total = sorted_term_scores_total[:top_n_total]

# Print the top N keywords and their average TF-IDF scores
print(f"Top {top_n_total} overall keywords for the entire corpus:")
for word_total, score_total in top_keywords_total:
    print(f"  {word_total}: {score_total:.3f}")
# Out:
# Top 10 overall keywords for the entire corpus:
#   issue: 0.037
#   chatgpt: 0.035
#   file: 0.035
#   code: 0.033
#   like: 0.028
#   link: 0.027
#   create: 0.025
#   image: 0.025
#   prompt: 0.025
#   use: 0.024

# %%
# Print the top N keywords and their average TF-IDF scores
print(f"Top {top_n_closed} overall keywords for the closed corpus:")
for word_closed, score_closed in top_keywords_closed:
    print(f"  {word_closed}: {score_closed:.3f}")

# Print the top N keywords and their average TF-IDF scores
print(f"Top {top_n_open} overall keywords for the open corpus:")
for word_open, score_open in top_keywords_open:
    print(f"  {word_open}: {score_open:.3f}")

# Print the top N keywords and their average TF-IDF scores
print(f"Top {top_n_total} overall keywords for the entire corpus:")
for word_total, score_total in top_keywords_total:
    print(f"  {word_total}: {score_total:.3f}")
# Out:
# Top 10 overall keywords for the closed corpus:
#   issue: 0.069
#   solar: 0.043
#   resolve: 0.042
#   tutor: 0.042
#   like: 0.041
#   jushbjj: 0.041
#   link: 0.039
#   ai: 0.038
#   debit: 0.038
#   config: 0.038
# Top 10 overall keywords for the open corpus:
#   file: 0.062
#   const: 0.060
#   request: 0.058
#   task: 0.051
#   pull: 0.049
#   feature: 0.049
#   key: 0.049
#   code: 0.049
#   require: 0.047
#   review: 0.044
# Top 10 overall keywords for the entire corpus:
#   issue: 0.037
#   chatgpt: 0.035
#   file: 0.035
#   code: 0.033
#   like: 0.028
#   link: 0.027
#   create: 0.025
#   image: 0.025
#   prompt: 0.025
#   use: 0.024
